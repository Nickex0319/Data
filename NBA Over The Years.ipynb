# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

df = pd.read_excel(r'C:\Users\Nicholas\Desktop\nba_stats.xlsx')

# %%
df
# Out:
#           Year       Season_type  PLAYER_ID  RANK                  PLAYER  \
# 0      1979-80  Regular%20Season      76804     1           George Gervin
# 1      1979-80  Regular%20Season      77449     2            Moses Malone
# 2      1979-80  Regular%20Season      76681     3           Julius Erving
# 3      1979-80  Regular%20Season      76753     4              World Free
# 4      1979-80  Regular%20Season      76003     5     Kareem Abdul-Jabbar
# ...        ...               ...        ...   ...                     ...
# 27029  2022-23          Playoffs     203648   194  Thanasis Antetokounmpo
# 27030  2022-23          Playoffs    1628418   194           Thomas Bryant
# 27031  2022-23          Playoffs       2617   194           Udonis Haslem
# 27032  2022-23          Playoffs    1628427   194           Vlatko Cancar
# 27033  2022-23          Playoffs    1631111   194       Wendell Moore Jr.
#
#           TEAM_ID TEAM  GP   MIN   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# ...

# %%
df.isna().sum()
# Out:
# Year           0
# Season_type    0
# PLAYER_ID      0
# RANK           0
# PLAYER         0
# TEAM_ID        0
# TEAM           0
# GP             0
# MIN            0
# FGM            0
# FGA            0
# FG_PCT         0
# FG3M           0
# FG3A           0
# FG3_PCT        0
# FTM            0
# FTA            0
# FT_PCT         0
# OREB           0
# DREB           0
# REB            0
# AST            0
# STL            0
# BLK            0
# TOV            0
# PF             0
# PTS            0
# EFF            0
# AST_TOV        0
# STL_TOV        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27034 entries, 0 to 27033
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         27034 non-null  object
#  1   Season_type  27034 non-null  object
#  2   PLAYER_ID    27034 non-null  int64
#  3   RANK         27034 non-null  int64
#  4   PLAYER       27034 non-null  object
#  5   TEAM_ID      27034 non-null  int64
#  6   TEAM         27034 non-null  object
#  7   GP           27034 non-null  int64
#  8   MIN          27034 non-null  int64
#  9   FGM          27034 non-null  int64
#  10  FGA          27034 non-null  int64
#  11  FG_PCT       27034 non-null  float64
#  12  FG3M         27034 non-null  int64
#  13  FG3A         27034 non-null  int64
#  14  FG3_PCT      27034 non-null  float64
#  15  FTM          27034 non-null  int64
#  16  FTA          27034 non-null  int64
#  17  FT_PCT       27034 non-null  float64
# ...

# %%
df['season_start_year'] = df['Year'].str[:4].astype(int)

# %%
df['TEAM'].unique().size
# Out:
# 42

# %%
df['TEAM'].unique()
# Out:
# array(['SAN', 'HOU', 'PHL', 'SDC', 'LAL', 'DEN', 'UTH', 'WAS', 'KCK',
#        'CLE', 'SEA', 'PHX', 'NYK', 'BOS', 'MIL', 'CHI', 'NJN', 'IND',
#        'ATL', 'DET', 'POR', 'GOS', 'DAL', 'LAC', 'SAC', 'CHH', 'MIA',
#        'MIN', 'ORL', 'TOR', 'VAN', 'UTA', 'GSW', 'PHI', 'SAS', 'MEM',
#        'NOH', 'CHA', 'NOK', 'OKC', 'BKN', 'NOP'], dtype=object)

# %%
df['TEAM'].replace(to_replace=['NOP', 'NOH'], value='NO',inplace=True)

df['TEAM'].replace(to_replace=['SDC'], value='LAC',inplace=True)

df['TEAM'].replace(to_replace=['KCK'], value='SAC',inplace=True)

df['TEAM'].replace(to_replace=['SEA'], value='OKC',inplace=True)

df['TEAM'].replace(to_replace=['NJN'], value='BKN',inplace=True)

df['TEAM'].replace(to_replace=['KCK'], value='SAC',inplace=True)

df['TEAM'].replace(to_replace=['GOS'], value='GSW',inplace=True)

df['TEAM'].replace(to_replace=['UTA'], value='UTH',inplace=True)

df['TEAM'].replace(to_replace=['PHI'], value='PHL',inplace=True) 

df['TEAM'].replace(to_replace=['CHA'], value='CHH',inplace=True)

df['TEAM'].replace(to_replace=['NOK'], value='NO',inplace=True)

df['TEAM'].replace(to_replace=['VAN'], value='MEM',inplace=True)

df['TEAM'].replace(to_replace=['SAN'], value='SAS',inplace=True)

df['TEAM'].unique().size
# Out:
# 30

# %%
df['Season_type'].replace('Regular%20Season', 'RS', inplace =True)

# %%
rs_df = df[df['Season_type'] == 'RS']
playoff_df = df[df['Season_type'] == 'Playoffs']

# %%
total_cols = ['MIN','FGM','FGA','FG3M','FG3A','FTM','FTA',
              'OREB','DREB','REB','AST','STL','BLK','TOV','PF','PTS']

# %%
df.corr(numeric_only = True)
# Out:
#                    PLAYER_ID      RANK   TEAM_ID        GP       MIN  \
# PLAYER_ID           1.000000  0.228503  0.006792 -0.078816 -0.099617
# RANK                0.228503  1.000000  0.015412 -0.204180 -0.444049
# TEAM_ID             0.006792  0.015412  1.000000  0.010750  0.005674
# GP                 -0.078816 -0.204180  0.010750  1.000000  0.889169
# MIN                -0.099617 -0.444049  0.005674  0.889169  1.000000
# FGM                -0.079437 -0.499588  0.000713  0.776388  0.936219
# FGA                -0.080400 -0.494371  0.001839  0.786350  0.942201
# FG_PCT             -0.018752 -0.212849 -0.002445  0.228511  0.227018
# FG3M                0.105195 -0.273580 -0.007855  0.454591  0.543352
# FG3A                0.111726 -0.277446 -0.008096  0.476200  0.565485
# FG3_PCT             0.121604 -0.148589  0.004534  0.166641  0.196305
# FTM                -0.107634 -0.479574  0.004708  0.671119  0.842690
# FTA                -0.113227 -0.472308  0.006516  0.687639  0.851069
# ...

# %%
# These are totals. the more a player plays they naturally going to
# accumulate more stats so its not a fair representation of player 
# tendencies in terms of what they frequently do well 
# and what they dont frequently do well

# %%
data_per_min = rs_df.groupby(['PLAYER','PLAYER_ID','Year'])[total_cols].sum().reset_index()

for col in data_per_min.columns[4:]:
    data_per_min[col] = data_per_min[col]/data_per_min['MIN']

data_per_min['FG%'] = data_per_min['FGM']/data_per_min['FGA']
data_per_min['3PT%'] = data_per_min['FG3M']/data_per_min['FG3A']
data_per_min['FT%'] = data_per_min['FTM']/data_per_min['FTA']
data_per_min['FG3A%'] = data_per_min['FG3A']/data_per_min['FGA']
data_per_min['PTS/FGA'] = data_per_min['PTS']/data_per_min['FGA']
data_per_min['FG3M/FGM'] = data_per_min['FG3M']/data_per_min['FGM']
data_per_min['FTA/FGA'] = data_per_min['FTA']/data_per_min['FGA']
data_per_min['TRU%'] = 0.5*data_per_min['PTS']/(data_per_min['FGA']+0.475*data_per_min['FTA'])
data_per_min['AST_TOV'] = data_per_min['AST']/data_per_min['TOV']

data_per_min = data_per_min[data_per_min['MIN']>=50]
data_per_min.drop(columns='PLAYER_ID', inplace=True)

fig = px.imshow(data_per_min.corr(numeric_only = True))

fig.show()
# Out:
# <div>                            <div id="db8d64b1-334c-457a-8da9-2680047a362c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db8d64b1-334c-457a-8da9-2680047a362c")) {                    Plotly.newPlot(                        "db8d64b1-334c-457a-8da9-2680047a362c",                        [{"coloraxis":"coloraxis","name":"0","x":["MIN","FGM","FGA","FG3M","FG3A","FTM","FTA","OREB","DREB","REB","AST","STL","BLK","TOV","PF","PTS","FG%","3PT%","FT%","FG3A%","PTS\u002fFGA","FG3M\u002fFGM","FTA\u002fFGA","TRU%","AST_TOV"],"y":["MIN","FGM","FGA","FG3M","FG3A","FTM","FTA","OREB","DREB","REB","AST","STL","BLK","TOV","PF","PTS","FG%","3PT%","FT%","FG3A%","PTS\u002fFGA","FG3M\u002fFGM","FTA\u002fFGA","TRU%","AST_TOV"],"z":[[1.0,0.45279157901807193,0.333844380
# ...

# %% [markdown]
# # Correlation Insights

# %%
fig = px.histogram(x=rs_df['MIN'],histnorm='percent', width = 900, title = 'Minutes played Histogram (%)')
fig.show()
# Out:
# <div>                            <div id="9b7a7076-23fc-4409-b260-b38b01a4e895" class="plotly-graph-div" style="height:525px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b7a7076-23fc-4409-b260-b38b01a4e895")) {                    Plotly.newPlot(                        "9b7a7076-23fc-4409-b260-b38b01a4e895",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"x=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2934,3140,2812,2585,3143,2938,2674,3183,2885,2802,2969,2665,3150,2955,2582,2686,3029,3111,2510,2309,2647,2798,2306,2945,2937,2118,2676,2622,3226,2677,2316,2710,2795,2293,2744,2
# ...

# %%
#right skewed more data ponts on left makes sense since most dont get the shot/arent good enough and those that are good stay

#6.4 percent dont play more than 50 minutes

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=rs_df['MIN']/rs_df['GP'], histnorm='percent', name='RS',
                           xbins={'start':0,'end':46,'size':1}))
fig.add_trace(go.Histogram(x= playoff_df['MIN']/playoff_df['GP'], histnorm='percent',
                           name='Playoffs', xbins={'start':0,'end':46,'size':1}))
fig.update_layout(barmode='overlay')
fig.update_layout(
    title=dict(text="MIN/GP", font=dict(size=25), automargin=True, yref='paper')
)
fig.update_traces(opacity=0.5)

fig.show()
# Out:
# <div>                            <div id="bf663728-65bc-4c3d-b19e-9a89b796eae4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf663728-65bc-4c3d-b19e-9a89b796eae4")) {                    Plotly.newPlot(                        "bf663728-65bc-4c3d-b19e-9a89b796eae4",                        [{"histnorm":"percent","name":"RS","x":[37.61538461538461,38.292682926829265,36.05128205128205,38.01470588235294,38.329268292682926,35.829268292682926,39.3235294117647,39.2962962962963,35.18292682926829,34.170731707317074,36.207317073170735,32.5,38.41463414634146,36.03658536585366,31.48780487804878,34.883116883116884,36.9390243902439,37.9390243902439,32.17948717948718,30.786666666666665,32.28048780487805,35.87179487179487,28.825,36.358024691358025,36.2592592592592
# ...

# %%
#Regular season is somewhat normal
#lots of guys get chance to play
#Playoffs you have alot more guys on tail ends
#roster gets much tighter in playoffs

# %%
def hist_data(df=rs_df, min_MIN=0, min_GP=0):
    return df.loc[(df['MIN']>=min_MIN) & (df['GP']>=min_GP), 'MIN']/\
    df.loc[(df['MIN']>=min_MIN) & (df['GP']>=min_GP), 'GP']

# %%
((hist_data(rs_df,50,5)>=8)&(hist_data(rs_df,50,5)<=34)).mean()
# Out:
# 0.7986584876454739

# %%
((hist_data(playoff_df,5,1)>=8)&(hist_data(playoff_df,5,1)<=34)).mean()
# Out:
# 0.5756286750907044

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=rs_df['PTS']/rs_df['GP'], histnorm='percent', name='RS',
                           xbins={'start':0,'end':38,'size':1}))
fig.add_trace(go.Histogram(x= playoff_df['PTS']/playoff_df['GP'], histnorm='percent',
                           name='Playoffs', xbins={'start':0,'end':38,'size':1}))
fig.update_layout(barmode='overlay')
fig.update_layout(
    title=dict(text="Points per Game", font=dict(size=25), automargin=True, yref='paper')
)
fig.update_traces(opacity=0.5)
fig.show()
# Out:
# <div>                            <div id="5acc15e4-5dc4-45af-9ae8-dc1e6f110998" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5acc15e4-5dc4-45af-9ae8-dc1e6f110998")) {                    Plotly.newPlot(                        "5acc15e4-5dc4-45af-9ae8-dc1e6f110998",                        [{"histnorm":"percent","name":"RS","x":[33.14102564102564,25.841463414634145,26.923076923076923,30.220588235294116,24.804878048780488,23.79268292682927,27.985294117647058,22.950617283950617,22.658536585365855,22.195121951219512,22.146341463414632,21.853658536585368,21.71951219512195,21.28048780487805,20.902439024390244,21.7012987012987,20.24390243902439,20.048780487804876,20.94871794871795,21.506666666666668,19.097560975609756,20.064102564102566,19.4875,19.1234567
# ...

# %%
#Play off has more on right tail
#More players on tail scoring higher points per game.

# %% [markdown]
# # CHANGE OVER THE YEARS

# %%
change_df = df.groupby('season_start_year')[total_cols].sum().reset_index()
change_df['POSS_est'] = change_df['FGA']-change_df['OREB']+change_df['TOV']+0.44*change_df['FTA']
change_df = change_df[list(change_df.columns[0:2])+['POSS_est']+list(change_df.columns[2:-1])]

change_df['FG%'] = change_df['FGM']/change_df['FGA']
change_df['3PT%'] = change_df['FG3M']/change_df['FG3A']
change_df['FT%'] = change_df['FTM']/change_df['FTA']
change_df['AST%'] = change_df['AST']/change_df['FGM']
change_df['FG3A%'] = change_df['FG3A']/change_df['FGA']
change_df['PTS/FGA'] = change_df['PTS']/change_df['FGA']
change_df['FG3M/FGM'] = change_df['FG3M']/change_df['FGM']
change_df['FTA/FGA'] = change_df['FTA']/change_df['FGA']
change_df['TRU%'] = 0.5*change_df['PTS']/(change_df['FGA']+0.475*change_df['FTA'])
change_df['AST_TOV'] = change_df['AST']/change_df['TOV']

change_df
# Out:
#     season_start_year     MIN   POSS_est     FGM     FGA   FG3M   FG3A    FTM  \
# 0                1979  415530  182521.04   75120  155695   1334   4824  36583
# 1                1980  455253  197990.48   81266  166989    888   3705  41305
# 2                1981  455813  195365.92   81456  165819   1121   4252  40342
# 3                1982  475930  209065.80   85814  176861   1069   4478  41197
# 4                1983  494794  213826.80   88558  180237   1274   5035  46275
# 5                1984  483863  211384.40   87861  178779   1808   6403  45321
# 6                1985  476976  207680.68   85568  175135   1864   6571  45261
# 7                1986  490020  210896.40   86378  179740   2926   9691  47334
# 8                1987  493640  209286.68   85911  178923   3268  10342  45594
# 9                1988  525160  225425.88   91949  192817   4709  14632  48193
# 10               1989  569505  238890.60   97651  205037   5199  15778  51570
# ...

# %%
change_per48_df = change_df.copy()

#average stats per 48 minutes for team
for col in change_per48_df.columns[2:18]:
    change_per48_df[col] = (change_per48_df[col]/change_per48_df['MIN'])*48*5

    
change_per48_df.drop(columns='MIN', inplace=True)

# %%
fig = go.Figure()
for col in change_per48_df.columns[1:]:
    fig.add_trace(go.Scatter(x=change_per48_df['season_start_year'],
                             y=change_per48_df[col], name=col))
    
fig.update_layout(
    title=dict(text="Change of statistics over the years 1979-2023", font=dict(size=25), automargin=True, yref='paper')
)
fig.show()
# Out:
# <div>                            <div id="068aa392-aed3-40e4-9065-161f1eeedb6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("068aa392-aed3-40e4-9065-161f1eeedb6f")) {                    Plotly.newPlot(                        "068aa392-aed3-40e4-9065-161f1eeedb6f",                        [{"name":"POSS_est","x":[1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[105.41970399249152,104.37650097857676,102.86635264900299,105.42683167692728,103.71676293568635,104.8483889034706,104.49868169467646,103.29197991918697,101.75189044647921,103.02043415340087,100.67294229199042,100.04370
# ...

# %%
#1994-1997 the 3 point line went from 23, 9 inches (22 feet at the corners)
# to uniform 22 feet around
#changed back afterwards
#explains the rapid spike at 1994 in FG3M

# %%
#rebounding has decreased. Due to game being more spread out with people able to hit 3s

#Explosion of FG3A 2010-2011 because of players like curry

# %%
#Offensive rebounds are on decline since teams are worried about fast breaks

# %% [markdown]
# # RS to Playoff

# %%
rs_change_df = rs_df.groupby('season_start_year')[total_cols].sum().reset_index()
playoffs_change_df = playoff_df.groupby('season_start_year')[total_cols].sum().reset_index()

for i in [rs_change_df,playoffs_change_df]:
    i['POSS_est'] = i['FGA']-i['OREB']+i['TOV']+0.44*i['FTA']
    i['POSS_per_48'] = (i['POSS_est']/i['MIN'])*48*5
    
    i['FG%'] = i['FGM']/i['FGA']
    i['3PT%'] = i['FG3M']/i['FG3A']
    i['FT%'] = i['FTM']/i['FTA']
    i['AST%'] = i['AST']/i['FGM']
    i['FG3A%'] = i['FG3A']/i['FGA']
    i['PTS/FGA'] = i['PTS']/i['FGA']
    i['FG3M/FGM'] = i['FG3M']/i['FGM']
    i['FTA/FGA'] = i['FTA']/i['FGA']
    i['TRU%'] = 0.5*i['PTS']/(i['FGA']+0.475*i['FTA'])
    i['AST_TOV'] = i['AST']/i['TOV']
    for col in i.columns[2:18]:
        i[col] = (i[col]/i['MIN'])*5
    i.drop(columns=['MIN','POSS_per_48'], inplace=True)

# %%
rs_change_df.head(5)
# Out:
#    season_start_year       FGM       FGA      FG3M      FG3A       FTM  \
# 0               1979  0.906114  1.876297  0.015833  0.057091  0.441252
# 1               1980  0.896640  1.839057  0.009746  0.040509  0.455112
# 2               1981  0.895090  1.818491  0.012339  0.046624  0.443019
# 3               1982  0.901877  1.857852  0.011108  0.046672  0.433683
# 4               1983  0.898233  1.825208  0.012268  0.049105  0.465886
#
#         FTA      OREB      DREB       REB       AST       STL       BLK  \
# 0  0.575454  0.312657  0.617410  0.930067  0.537127  0.198005  0.111823
# 1  0.606087  0.305905  0.606157  0.912062  0.522929  0.185808  0.113490
# 2  0.594193  0.297345  0.605599  0.902943  0.527411  0.177710  0.111504
# 3  0.585994  0.307302  0.613977  0.921279  0.536839  0.184337  0.116087
# 4  0.613288  0.293226  0.595631  0.888857  0.541017  0.175706  0.109579
#
#         TOV        PF       PTS  POSS_est       FG%      3PT%       FT%  \
# ...

# %%
playoffs_change_df.tail(5)
# Out:
#     season_start_year       FGM       FGA      FG3M      FG3A       FTM  \
# 39               2018  0.793643  1.792863  0.234120  0.679098  0.399462
# 40               2019  0.801985  1.754864  0.269941  0.749739  0.388491
# 41               2020  0.832683  1.801078  0.258743  0.710994  0.362630
# 42               2021  0.793873  1.742359  0.255297  0.719496  0.368656
# 43               2022  0.832860  1.807739  0.249611  0.710831  0.356341
#
#          FTA      OREB      DREB       REB       AST       STL       BLK  \
# 39  0.509606  0.210481  0.717573  0.928054  0.474526  0.145979  0.100463
# 40  0.492984  0.181868  0.709185  0.891053  0.472210  0.145295  0.087948
# 41  0.461152  0.205580  0.694654  0.900234  0.455299  0.138394  0.091206
# 42  0.469699  0.194911  0.678840  0.873750  0.476156  0.147558  0.094825
# 43  0.448511  0.213953  0.679367  0.893320  0.491819  0.141278  0.098956
#
#          TOV        PF       PTS  POSS_est       FG%      3PT%       FT%  \
# ...

# %%
#Lets see which stats go up in the playoffs and which go down

# %%
comp_change_df = round(100*(playoffs_change_df-rs_change_df)/rs_change_df,3)
comp_change_df['season_start_year'] = list(range(1979,2023))
comp_change_df.tail(5)
# Out:
#     season_start_year    FGM    FGA   FG3M   FG3A    FTM    FTA    OREB  \
# 39               2018 -6.633 -2.870 -0.429  2.537  9.195  6.749  -1.686
# 40               2019 -5.102 -4.462  6.897  6.272  5.184  3.157 -12.719
# 41               2020 -2.437 -1.637 -1.603 -0.887  3.201  2.046   0.991
# 42               2021 -5.660 -4.528 -0.918 -1.264  5.093  3.712  -8.953
# 43               2022 -4.041 -0.989 -2.181  0.480 -6.306 -7.810  -0.836
#
#      DREB    REB     AST     STL     BLK     TOV     PF    PTS  POSS_est  \
# 39 -0.395 -0.691  -6.721  -7.578  -1.975  -5.662  5.755 -3.483    -2.406
# 40 -1.340 -3.898  -6.367  -8.147 -13.210  -4.245  4.545 -2.148    -2.870
# 41 -2.686 -1.870 -11.363 -11.746  -9.606 -13.101  6.306 -1.489    -3.038
# 42 -3.946 -5.110  -6.748  -6.655  -2.876  -0.299  9.705 -3.481    -2.734
# 43 -0.447 -0.540  -6.047  -6.272   2.840  -9.985 -1.765 -4.204    -2.888
#
#       FG%   3PT%    FT%   AST%   FG3A%  PTS/FGA  FG3M/FGM  FTA/FGA   TRU%  \
# ...

# %%
#playoff games are more physical look at PF

# %%
fig = go.Figure()
for col in comp_change_df.columns[1:]:
    fig.add_trace(go.Scatter(x=comp_change_df['season_start_year'],
                             y=comp_change_df[col], name=col))
    
fig.update_layout(
    title=dict(text="Change of statistics over the years 1979-2023 (RS vs. Playoffs)", font=dict(size=25), automargin=True, yref='paper')
)
fig.show()
# Out:
# <div>                            <div id="5555cc77-0747-4e64-a20a-0bc4ccabae9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5555cc77-0747-4e64-a20a-0bc4ccabae9a")) {                    Plotly.newPlot(                        "5555cc77-0747-4e64-a20a-0bc4ccabae9a",                        [{"name":"FGM","x":[1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[-4.727,-8.219,-3.584,-0.852,-4.795,1.516,-0.418,-2.002,-4.502,-7.344,-3.934,-5.7,-6.356,-6.518,-12.301,-6.594,-7.453,-6.888,-6.935,-6.749,-8.575,-3.117,-5.019,-3.246,-7.886,-1.565,-1.311,-5.802,-7.193,-6.464,-6.025,-9.038,
# ...

# %%
#More FG3A back then when they were arguably worse at shooting 3s.
#More possesions in the playoffs
#FG3M are becoming even
#Higher scoring games
#OREB are more in the playoffs
#more physical game as shown by the change in fouls
